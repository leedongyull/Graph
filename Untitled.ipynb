# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('tmdb_5000_movies.csv',sep=',')
print(df.groupby('genres')[['vote_average','popularity','runtime']].mean())
macdo=df.groupby('genres')[['vote_average','popularity','runtime']].mean()
macdo.plot()
# Out:
#                                                     vote_average  popularity  \
# genres
# []                                                      2.335714    0.167952
# [{"id": 10402, "name": "Music"}, {"id": 10749, ...      6.566667    1.453119
# [{"id": 10402, "name": "Music"}, {"id": 12, "na...      6.600000   26.509175
# [{"id": 10402, "name": "Music"}, {"id": 18, "na...      6.700000   45.477802
# [{"id": 10402, "name": "Music"}, {"id": 18, "na...      6.350000   18.261216
# ...                                                          ...         ...
# [{"id": 99, "name": "Documentary"}, {"id": 28, ...      7.600000   14.045887
# [{"id": 99, "name": "Documentary"}, {"id": 35, ...      6.600000   10.400603
# [{"id": 99, "name": "Documentary"}, {"id": 35, ...      6.100000   14.752587
# [{"id": 99, "name": "Documentary"}, {"id": 36, ...      7.400000    3.284903
# [{"id": 99, "name": "Documentary"}]                     5.985294    2.830152
#
# ...
